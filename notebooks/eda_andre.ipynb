# %%
import pandas as pd

df = pd.read_parquet('../data/lending_club_case_train_dataset_cleaned.parquet')

# %%
df = df.dropna(subset=['default'])

# %%
df['default'] = df['default'].astype(int)

# %%
df['time_of_banking_days'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df['time_of_banking_months'] = (df['issue_d'].dt.year - df['earliest_cr_line'].dt.year) * 12 + (df['issue_d'].dt.month - df['earliest_cr_line'].dt.month)

# %%
print(df['time_of_banking_months'])
# Out:
# 0          323
# 1          152
# 2          121
# 3          190
# 4          191
#           ...
# 2925487    264
# 2925488    283
# 2925489    287
# 2925490    323
# 2925491    233
# Name: time_of_banking_months, Length: 1583646, dtype: int32

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

# Use hue to color based on the "default" column
sns.histplot(df[df['time_of_banking_months']<= 600], x='time_of_banking_months', hue='default', bins=30, kde=True, alpha=0.5,stat='probability', common_norm=False)

# Labels and title
plt.xlabel('Months of Banking')
plt.ylabel('Frequency')
plt.title('Months of Banking by Default Status')

plt.show()

# %%
plt.figure(figsize=(8, 5))

# Use hue to color based on the "default" column
sns.histplot(df[df['dti']<=100], x='dti', hue='default', bins=30, kde=True, alpha=0.5,stat='probability', common_norm=False)

# Labels and title
plt.xlabel('dti')
plt.ylabel('Frequency')
plt.title('Debt to Income Ratio')

plt.show()

# %%
# Create pivot table with normalized proportions
delinquency_pivot_table = pd.crosstab(df['delinq_2yrs'], df['default'], normalize='index')

# Display table
print(delinquency_pivot_table)

plt.show()
# Out:
# default             0         1
# delinq_2yrs
# 0            0.812180  0.187820
# 1            0.802475  0.197525
# 2            0.793699  0.206301
# 3            0.783801  0.216199
# 4            0.783917  0.216083
# 5            0.779871  0.220129
# 6            0.792440  0.207560
# 7            0.770093  0.229907
# 8            0.787975  0.212025
# 9            0.775717  0.224283
# 10           0.782178  0.217822
# 11           0.771218  0.228782
# 12           0.736842  0.263158
# 13           0.760331  0.239669
# 14           0.744681  0.255319
# 15           0.825397  0.174603
# 16           0.714286  0.285714
# 17           0.684211  0.315789
# 18           0.791667  0.208333
# 19           0.705882  0.294118
# 20           0.785714  0.214286
# 21           0.600000  0.400000
# 22           1.000000  0.000000
# 24           1.000000  0.000000
# 25           0.500000  0.500000
# 26           1.000000  0.000000
# 27           0.000000  1.000000
# 28           1.000000  0.000000
# 29           1.000000  0.000000
# 30           1.000000  0.000000
# 32           1.000000  0.000000
# 36           0.000000  1.000000
# 39           1.000000  0.000000
# 42           1.000000  0.000000

# %%
# Reset index for plotting
# Filter the pivot table to keep only delinq_2yrs values up to 20
delinquency_pivot_table = delinquency_pivot_table[delinquency_pivot_table['delinq_2yrs'] <= 20]

delinquency_pivot_table.reset_index(inplace=True)

# Line chart for better trend visualization
plt.figure(figsize=(8, 5))
plt.plot(delinquency_pivot_table['delinq_2yrs'], delinquency_pivot_table[0], marker='o', linestyle='-', label='Default = 0')
plt.plot(delinquency_pivot_table['delinq_2yrs'], delinquency_pivot_table[1], marker='s', linestyle='--', label='Default = 1')

# Labels and title
plt.xlabel('Delinquencies in 2 Years')
plt.ylabel('Proportion of Defaults')
plt.title('Distribution of Default by Delinquencies (delinq_2yrs)')
plt.legend(title='Default')
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(8, 5))

# Use hue to color based on the "default" column
sns.histplot(df, x='fico_range_low', hue='default', bins=30, kde=True, alpha=0.5,stat='probability', common_norm=False)

# Labels and title
plt.xlabel('fico_range_low')
plt.ylabel('Frequency')
plt.title('fico_range_low')

plt.show()

# %%
plt.figure(figsize=(8, 5))

# Use hue to color based on the "default" column
sns.histplot(df, x='fico_range_high', hue='default', bins=30, kde=True, alpha=0.5,stat='probability', common_norm=False)

# Labels and title
plt.xlabel('fico_range_high')
plt.ylabel('Frequency')
plt.title('fico_range_high')

plt.show()

# %%
# Create pivot table with normalized proportions
inqueries_pivot_table = pd.crosstab(df['inq_last_6mths'], df['default'], normalize='index')

# Display table
print(inqueries_pivot_table)

plt.show()
# Out:
# default                0         1
# inq_last_6mths
# -1              1.000000  0.000000
# 0               0.829710  0.170290
# 1               0.793668  0.206332
# 2               0.765948  0.234052
# 3               0.742668  0.257332
# 4               0.726895  0.273105
# 5               0.722109  0.277891
# 6               0.761506  0.238494
# 7               0.750000  0.250000
# 8               0.818182  0.181818

# %%
df_train = df[['time_of_banking_months',
                'dti',
                'delinq_2yrs', 
                'fico_range_low',
                'fico_range_high',
                'inq_last_6mths',
                'default']].copy()

# %%
df_train.head()
# Out:
# /Users/andre.luis/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /Users/andre.luis/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#    time_of_banking_months       dti  delinq_2yrs  fico_range_low  \
# 0                     323  27.65625            0             735
# 1                     152   1.00000            0             740
# 2                     121   8.71875            0             735
# 3                     190  20.00000            0             690
# 4                     191  17.93750            0             695
#
#    fico_range_high  inq_last_6mths  default
# 0              739               1        0
# 1              744               5        1
# 2              739               2        0
# 3              694               1        0
# 4              699               0        0

# %%
import numpy as np
import pandas as pd
import shap
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, average_precision_score

# Select relevant features and target
features = ['time_of_banking_months', 'dti', 'delinq_2yrs', 
            'fico_range_low', 'fico_range_high', 'inq_last_6mths']
target = 'default'

# Drop NA values (ensure clean data)
df_train = df_train.dropna(subset=features + [target])

# Split data into train and test sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(
    df_train[features], df_train[target], test_size=0.2, random_state=42, stratify=df[target]
)

# Initialize XGBoost model
model = xgb.XGBClassifier(
    objective='binary:logistic', 
    eval_metric='logloss', 
    use_label_encoder=False,
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=5,
    subsample=0.8, 
    colsample_bytree=0.8, 
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Calculate metrics
logloss = log_loss(y_test, y_pred_proba)
pr_auc = average_precision_score(y_test, y_pred_proba)

print(f'Log Loss: {logloss:.4f}')
print(f'PR AUC: {pr_auc:.4f}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[55], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import shap
#       4 import xgboost as xgb
#       5 import matplotlib.pyplot as plt
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/shap/__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/shap/_explanation.py:13
#      10 import sklearn
#      11 from slicer import Alias, Obj, Slicer
# ---> 13 from .utils._exceptions import DimensionError
#      14 from .utils._general import OpChain
#      16 op_chain_root = OpChain("shap.Explanation")
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/shap/utils/__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)
#      20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/shap/utils/_clustering.py:8
#       6 import scipy.spatial
#       7 import sklearn
# ----> 8 from numba import njit
#      10 from ._show_progress import show_progress
#      13 def partition_tree(X, metric="correlation"):
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File ~/lending_club/ds_lending_club/.venv/lib/python3.11/site-packages/numba/__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 1):
#      43     msg = (f"Numba needs NumPy 2.1 or less. Got NumPy "
#      44            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.1 or less. Got NumPy 2.2.

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.2
